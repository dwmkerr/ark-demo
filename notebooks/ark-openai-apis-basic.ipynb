# %% [markdown]
# # ARK OpenAI API - Basic Demo
#
# A simple, non-interactive demonstration of ARK's OpenAI-compatible API.
# This notebook:
# 1. Configures the OpenAI client for ARK
# 2. Lists available models/targets
# 3. Sends a basic completion request to the default model

# %%
# Install OpenAI client
# !pip install openai

from openai import OpenAI

# Configuration
ARK_ENDPOINT = "http://ark-api.default.127.0.0.1.nip.io:8080/openai/v1"
API_KEY = "dummy-key"

print(f"ARK Endpoint: {ARK_ENDPOINT}")
print(f"API Key: {API_KEY}")

# Create OpenAI client
client = OpenAI(
    base_url=ARK_ENDPOINT,
    api_key=API_KEY
)

print("Configuration complete")
# Out:
# Requirement already satisfied: openai in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (1.107.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from openai) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from openai) (0.11.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from openai) (2.11.7)
# Requirement already satisfied: sniffio in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: certifi in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from httpx<1,>=0.23.0->openai) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai) (0.4.0)
# ARK Endpoint: http://ark-api.default.127.0.0.1.nip.io:8080/openai/v1
# API Key: dummy-key
# Configuration complete

# %%
# List available targets (models, agents, teams, tools)
print("Available targets in ARK:")
print("=" * 40)

try:
    targets = client.models.list()
    target_names = [target.id for target in targets.data]
    
    for target in target_names:
        print(f"  - {target}")
        
    print(f"\nTotal targets: {len(target_names)}")
    
except Exception as e:
    print(f"Error listing targets: {e}")
# Out:
# Available targets in ARK:
# ========================================
#   - agent/ark-pentester
#   - agent/aws-operator-agent
#   - agent/bedrock-test-agent
#   - agent/code-reviewer
#   - agent/deep-research
#   - agent/github-agent
#   - agent/github-dev-assistant
#   - agent/idea-generation
#   - agent/noah
#   - agent/planner
#   - agent/sample-agent
#   - agent/team-leader
#   - team/coding-team
#   - team/testing-team
#   - model/claude-3-5-haiku
#   - model/claude-3-5-sonnet
#   - model/claude-4-opus
#   - model/claude-haiku-bedrock
#   - model/default
#   - model/gemini-1-5-flash
#   - model/gemini-2-5-flash-lite
#   - model/test1
#   - tool/ark-mcp-list-agents
#   - tool/ark-mcp-query-agent
#   - tool/get-coordinates
#   - tool/github-add-comment-to-pending-review
#   - tool/github-add-issue-comment
#   - tool/github-add-sub-issue
#   - tool/github-assign-copilot-to-issue
#   - tool/github-cancel-workflow-run
#   - tool/github-create-and-submit-pull-request-review
#   - tool/github-create-branch
#   - tool/github-create-gist
#   - tool/github-create-issue
#   - tool/github-create-or-update-file
#   - tool/github-create-pending-pull-request-review
#   - tool/github-create-pull-request
#   - tool/github-create-pull-request-with-copilot
#   - tool/github-create-repository
#   - tool/github-delete-file
#   - tool/github-delete-pending-pull-request-review
#   - tool/github-delete-workflow-run-logs
#   - tool/github-dismiss-notification
#   - tool/github-download-workflow-run-artifact
#   - tool/github-fork-repository
#   - tool/github-get-code-scanning-alert
#   - tool/github-get-commit
#   - tool/github-get-dependabot-alert
#   - tool/github-get-discussion
#   - tool/github-get-discussion-comments
#   - tool/github-get-file-contents
#   - tool/github-get-global-security-advisory
#   - tool/github-get-issue
#   - tool/github-get-issue-comments
#   - tool/github-get-job-logs
#   - tool/github-get-latest-release
#   - tool/github-get-me
#   - tool/github-get-notification-details
#   - tool/github-get-pull-request
#   - tool/github-get-pull-request-diff
#   - tool/github-get-pull-request-files
#   - tool/github-get-pull-request-review-comments
#   - tool/github-get-pull-request-reviews
#   - tool/github-get-pull-request-status
#   - tool/github-get-release-by-tag
#   - tool/github-get-secret-scanning-alert
#   - tool/github-get-tag
#   - tool/github-get-team-members
#   - tool/github-get-teams
#   - tool/github-get-workflow-run
#   - tool/github-get-workflow-run-logs
#   - tool/github-get-workflow-run-usage
#   - tool/github-list-branches
#   - tool/github-list-code-scanning-alerts
#   - tool/github-list-commits
#   - tool/github-list-dependabot-alerts
#   - tool/github-list-discussion-categories
#   - tool/github-list-discussions
#   - tool/github-list-gists
#   - tool/github-list-global-security-advisories
#   - tool/github-list-issue-types
#   - tool/github-list-issues
#   - tool/github-list-notifications
#   - tool/github-list-org-repository-security-advisories
#   - tool/github-list-pull-requests
#   - tool/github-list-releases
#   - tool/github-list-repository-security-advisories
#   - tool/github-list-secret-scanning-alerts
#   - tool/github-list-starred-repositories
#   - tool/github-list-sub-issues
#   - tool/github-list-tags
#   - tool/github-list-workflow-jobs
#   - tool/github-list-workflow-run-artifacts
#   - tool/github-list-workflow-runs
#   - tool/github-list-workflows
#   - tool/github-manage-notification-subscription
#   - tool/github-manage-repository-notification-subscription
#   - tool/github-mark-all-notifications-read
#   - tool/github-merge-pull-request
#   - tool/github-push-files
#   - tool/github-remove-sub-issue
#   - tool/github-reprioritize-sub-issue
#   - tool/github-request-copilot-review
#   - tool/github-rerun-failed-jobs
#   - tool/github-rerun-workflow-run
#   - tool/github-run-workflow
#   - tool/github-search-code
#   - tool/github-search-issues
#   - tool/github-search-orgs
#   - tool/github-search-pull-requests
#   - tool/github-search-repositories
#   - tool/github-search-users
#   - tool/github-star-repository
#   - tool/github-submit-pending-pull-request-review
#   - tool/github-unstar-repository
#   - tool/github-update-gist
#   - tool/github-update-issue
#   - tool/github-update-pull-request
#   - tool/github-update-pull-request-branch
#   - tool/noah-mcp-aas-runtime-101
#   - tool/noah-mcp-ark-status
#   - tool/noah-mcp-bash
#   - tool/noah-mcp-helm
#   - tool/noah-mcp-kubectl
#   - tool/noah-mcp-psql
#   - tool/noah-mcp-python
#   - tool/noah-mcp-rabbitmq-admin
#   - tool/noah-mcp-rabbitmqctl
#   - tool/noah-mcp-system-info
#   - tool/reverse-tool-reverse-message
#
# Total targets: 130

# %%
# Send a completion request to the default model
print("Sending completion request to default model:")
print("=" * 50)

try:
    response = client.chat.completions.create(
        model="model/default",
        messages=[
            {"role": "user", "content": "Hello! Please tell me about ARK in exactly one sentence."}
        ],
        max_tokens=100
    )
    
    print(f"Request: Hello! Please tell me about ARK in exactly one sentence.")
    print(f"Response: {response.choices[0].message.content}")
    print(f"Model used: {response.model if hasattr(response, 'model') else 'model/default'}")
    print(f"Tokens used: {response.usage.total_tokens if response.usage else 'N/A'}")
    
    print("\nBasic ARK OpenAI API demo completed successfully!")
    
except Exception as e:
    print(f"Error sending completion: {e}")
# Out:
# Sending completion request to default model:
# ==================================================
# Error sending completion: Error code: 500 - {'detail': 'Query execution failed: No error details available'}
